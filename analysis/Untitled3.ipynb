# %%
# %load_ext rpy2.ipython

from fig_builder import (
    TwinsFiguresData,
    TwinsFigures,
    condense_and_label_organism_positions,
)
from random import shuffle
from plotnine import *
import pandas as pd
import warnings
from glob import glob
from os.path import isfile
from os import environ

warnings.filterwarnings('ignore')

fig_data = TwinsFiguresData()
figs = TwinsFigures(fig_data)
ORGANISM = 'Chryseobacterium_indoltheticum'
SPARSE_N = 100
environ['CAP2_TMP_DIR'] = '/home/dcdanko/Data/cap_tmp'

# %%
organisms = []
with open('strain_list.txt') as f:
    for line in f:
        organisms.append(line.strip())
shuffle(organisms)

transferred = {}
for organism in organisms:
    print('trying', organism)
    try:
        positions, pileup = condense_and_label_organism_positions(figs, organism)
        if positions.shape[0]:
            print('transferred', organism)
            transferred[organism] = (positions, pileup)
    except:
        print('error', organism)
        
list(transferred.keys())
# Out:
# trying Bacillus tequilensis
# transferred Bacillus tequilensis
# trying Parashewanella tropica
# transferred Parashewanella tropica
# trying Exiguobacterium antarcticum
# transferred Exiguobacterium antarcticum
# trying Providencia heimbachae
# transferred Providencia heimbachae
# trying Methylocystis heyeri
# transferred Methylocystis heyeri
# trying Enterocloster bolteae
# error Enterocloster bolteae
# trying Staphylococcus sciuri
# transferred Staphylococcus sciuri
# trying Bacillus pseudofirmus
# error Bacillus pseudofirmus
# trying Geobacillus stearothermophilus
# transferred Geobacillus stearothermophilus
# trying Hafnia alvei
# error Hafnia alvei
# trying Nocardioides euryhalodurans
# transferred Nocardioides euryhalodurans
# trying Bacteroides caccae
# transferred Bacteroides caccae
# trying Nostoc flagelliforme
# transferred Nostoc flagelliforme
# trying Aggregatibacter aphrophilus
# transferred Aggregatibacter aphrophilus
# trying Cronobacter condimenti
# transferred Cronobacter condimenti
# trying Lactobacillus murinus
# transferred Lactobacillus murinus
# trying Gordonibacter urolithinfaciens
# transferred Gordonibacter urolithinfaciens
# trying Actinobacillus succinogenes
# transferred Actinobacillus succinogenes
# trying Otariodibacter oris
# transferred Otariodibacter oris
# trying Tetragenococcus koreensis
# transferred Tetragenococcus koreensis
# trying Leptotrichia shahii
# error Leptotrichia shahii
# trying Prevotella ruminicola
# transferred Prevotella ruminicola
# trying Planococcus rifietoensis
# transferred Planococcus rifietoensis
# trying Methylacidiphilum infernorum
# error Methylacidiphilum infernorum
# trying Athalassotoga saccharophila
# error Athalassotoga saccharophila
# trying Kitasatospora albolonga
# error Kitasatospora albolonga
# trying Parachlamydia acanthamoebae
# transferred Parachlamydia acanthamoebae
# trying Mariprofundus ferrinatatus
# error Mariprofundus ferrinatatus
# trying Caldithrix abyssi
# error Caldithrix abyssi
# trying Shewanella chilikensis
# error Shewanella chilikensis
# trying Haloplanus rallus
# error Haloplanus rallus
# trying Methanospirillum hungatei
# error Methanospirillum hungatei
# trying Lysinibacillus varians
# error Lysinibacillus varians
# trying Vibrio alginolyticus
# transferred Vibrio alginolyticus
# trying Roseburia intestinalis
# transferred Roseburia intestinalis
# trying Lysinibacillus timonensis
# transferred Lysinibacillus timonensis
# trying Atlantibacter hermannii
# transferred Atlantibacter hermannii
# trying Kocuria indica
# error Kocuria indica
# trying Spirochaeta perfilievii
# transferred Spirochaeta perfilievii
# trying Campylobacter helveticus
# error Campylobacter helveticus
# trying Achromobacter ruhlandii
# transferred Achromobacter ruhlandii
# trying Aminobacterium colombiense
# transferred Aminobacterium colombiense
# trying Leptospirillum ferriphilum
# error Leptospirillum ferriphilum
# trying Salinimonas sediminis
# transferred Salinimonas sediminis
# trying Rothia aeria
# transferred Rothia aeria
# trying Corynebacterium maris
# error Corynebacterium maris
# trying Bifidobacterium catenulatum
# transferred Bifidobacterium catenulatum
# trying Pseudomonas antarctica
# error Pseudomonas antarctica
# trying Providencia rettgeri
# error Providencia rettgeri
# trying Pectobacterium parmentieri
# transferred Pectobacterium parmentieri
# trying Haemophilus pittmaniae
# transferred Haemophilus pittmaniae
# trying Geminocystis herdmanii
# error Geminocystis herdmanii
# trying Chryseobacterium indoltheticum
# transferred Chryseobacterium indoltheticum
# trying Gluconobacter albidus
# transferred Gluconobacter albidus
# trying Nonlabens dokdonensis
# transferred Nonlabens dokdonensis
# trying Streptomyces ficellus
# transferred Streptomyces ficellus
# trying Lactobacillus hokkaidonensis
# transferred Lactobacillus hokkaidonensis
# trying Kosakonia sacchari
# transferred Kosakonia sacchari
# trying Ketogulonicigenium robustum
# transferred Ketogulonicigenium robustum
# trying Bifidobacterium pseudocatenulatum
# transferred Bifidobacterium pseudocatenulatum
# trying Campylobacter lari
# transferred Campylobacter lari
# trying Crocosphaera subtropica
# transferred Crocosphaera subtropica
# trying Lactobacillus frumenti
# error Lactobacillus frumenti
# trying Fusobacterium necrophorum
# transferred Fusobacterium necrophorum
# trying Neisseria canis
# error Neisseria canis
# trying Leptotrichia hongkongensis
# transferred Leptotrichia hongkongensis
# trying Halarcobacter bivalviorum
# transferred Halarcobacter bivalviorum
# trying Stanieria cyanosphaera
# transferred Stanieria cyanosphaera
# trying Terriglobus roseus
# error Terriglobus roseus
# trying Serratia proteamaculans
# transferred Serratia proteamaculans
# trying Porphyromonas cangingivalis
# error Porphyromonas cangingivalis
# trying Brevibacterium siliguriense
# transferred Brevibacterium siliguriense
# trying Oscillatoria acuminata
# transferred Oscillatoria acuminata
# trying Helicobacter cetorum
# error Helicobacter cetorum
# trying Streptococcus viridans
# transferred Streptococcus viridans
# trying Vibrio gazogenes
# error Vibrio gazogenes
# trying Butyricimonas faecalis
# transferred Butyricimonas faecalis
# trying Bacillus miscanthi
# transferred Bacillus miscanthi
# trying Sphingobacterium daejeonense
# error Sphingobacterium daejeonense
# trying Bradyrhizobium lablabi
# error Bradyrhizobium lablabi
# trying Bacillus albus
# transferred Bacillus albus
# trying Streptococcus pyogenes
# error Streptococcus pyogenes
# trying Staphylospora marina
# transferred Staphylospora marina
# trying Yersinia canariae
# transferred Yersinia canariae
# trying Acholeplasma oculi
# transferred Acholeplasma oculi
# trying Acholeplasma axanthum
# transferred Acholeplasma axanthum
# trying Anoxybacillus amylolyticus
# transferred Anoxybacillus amylolyticus
# trying Staphylococcus simiae
# transferred Staphylococcus simiae
# trying Paenalcaligenes hominis
# error Paenalcaligenes hominis
# trying Mixta gaviniae
# error Mixta gaviniae
# trying Aerococcus urinaehominis
# transferred Aerococcus urinaehominis
# trying Salmonella bongori
# error Salmonella bongori
# trying Brenneria rubrifaciens
# transferred Brenneria rubrifaciens
# trying Gloeothece verrucosa
# error Gloeothece verrucosa
# trying Fictibacillus phosphorivorans
# error Fictibacillus phosphorivorans
# trying Neisseria elongata
# transferred Neisseria elongata
# trying Chitinophaga pinensis
# error Chitinophaga pinensis
# trying Octadecabacter temperatus
# error Octadecabacter temperatus
# trying Coriobacterium glomerans
# transferred Coriobacterium glomerans
# trying Paenibacillus kribbensis
# error Paenibacillus kribbensis
# trying Fusobacterium hwasookii
# error Fusobacterium hwasookii
# trying Xylella fastidiosa
# error Xylella fastidiosa
# ['Bacillus tequilensis',
#  'Parashewanella tropica',
#  'Exiguobacterium antarcticum',
#  'Providencia heimbachae',
#  'Methylocystis heyeri',
#  'Staphylococcus sciuri',
#  'Geobacillus stearothermophilus',
#  'Nocardioides euryhalodurans',
#  'Bacteroides caccae',
#  'Nostoc flagelliforme',
#  'Aggregatibacter aphrophilus',
#  'Cronobacter condimenti',
#  'Lactobacillus murinus',
#  'Gordonibacter urolithinfaciens',
#  'Actinobacillus succinogenes',
#  'Otariodibacter oris',
#  'Tetragenococcus koreensis',
#  'Prevotella ruminicola',
#  'Planococcus rifietoensis',
#  'Parachlamydia acanthamoebae',
#  'Vibrio alginolyticus',
#  'Roseburia intestinalis',
#  'Lysinibacillus timonensis',
#  'Atlantibacter hermannii',
#  'Spirochaeta perfilievii',
#  'Achromobacter ruhlandii',
#  'Aminobacterium colombiense',
#  'Salinimonas sediminis',
#  'Rothia aeria',
#  'Bifidobacterium catenulatum',
#  'Pectobacterium parmentieri',
#  'Haemophilus pittmaniae',
#  'Chryseobacterium indoltheticum',
#  'Gluconobacter albidus',
#  'Nonlabens dokdonensis',
#  'Streptomyces ficellus',
#  'Lactobacillus hokkaidonensis',
#  'Kosakonia sacchari',
#  'Ketogulonicigenium robustum',
#  'Bifidobacterium pseudocatenulatum',
#  'Campylobacter lari',
#  'Crocosphaera subtropica',
#  'Fusobacterium necrophorum',
#  'Leptotrichia hongkongensis',
#  'Halarcobacter bivalviorum',
#  'Stanieria cyanosphaera',
#  'Serratia proteamaculans',
#  'Brevibacterium siliguriense',
#  'Oscillatoria acuminata',
#  'Streptococcus viridans',
#  'Butyricimonas faecalis',
#  'Bacillus miscanthi',
#  'Bacillus albus',
#  'Staphylospora marina',
#  'Yersinia canariae',
#  'Acholeplasma oculi',
#  'Acholeplasma axanthum',
#  'Anoxybacillus amylolyticus',
#  'Staphylococcus simiae',
#  'Aerococcus urinaehominis',
#  'Brenneria rubrifaciens',
#  'Neisseria elongata',
#  'Coriobacterium glomerans']
